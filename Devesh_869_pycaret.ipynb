# %%
# check version
from pycaret.utils import version
version()
import pandas as pd

# %%
Cineplex1 = pd.read_csv(r"gen_X_train_features_v2.csv")

# %%
from pycaret.classification import *
reg1 = setup(Cineplex1, target = 'Has_US_Is_Voucher', remove_multicollinearity=True, multicollinearity_threshold = 0.6,
            normalize=True,normalize_method = 'zscore',transformation=True, handle_unknown_categorical = True,unknown_categorical_method = 'least_frequent', 
             combine_rare_levels = True, rare_level_threshold = 0.10, ignore_low_variance = True, session_id=123,
             remove_perfect_collinearity = True, create_clusters = True, cluster_iter = 20, polynomial_features = True, 
             polynomial_degree = 2, trigonometry_features = True, polynomial_threshold = 0.1, group_features = None, group_names = None, 
             feature_selection = True, feature_selection_threshold = 0.6, feature_interaction = True, feature_ratio = True, 
             interaction_threshold = 0.01, fix_imbalance = True, data_split_shuffle = True, 
             folds_shuffle = True, log_experiment = True, log_plots = True, log_profile = True, log_data = True,            
             experiment_name='cineplex')
# Out:
# <style  type="text/css" >
#     #T_50058efc_26f3_11eb_8e60_98fa9bd8217brow15_col1 {
#             background-color:  lightgreen;
#             background-color:  lightgreen;
#         }    #T_50058efc_26f3_11eb_8e60_98fa9bd8217brow17_col1 {
#             background-color:  lightgreen;
#             background-color:  lightgreen;
#         }    #T_50058efc_26f3_11eb_8e60_98fa9bd8217brow22_col1 {
#             background-color:  lightgreen;
#             background-color:  lightgreen;
#         }    #T_50058efc_26f3_11eb_8e60_98fa9bd8217brow23_col1 {
#             background-color:  lightgreen;
#             background-color:  lightgreen;
#         }    #T_50058efc_26f3_11eb_8e60_98fa9bd8217brow28_col1 {
#             background-color:  lightgreen;
#             background-color:  lightgreen;
#         }    #T_50058efc_26f3_11eb_8e60_98fa9bd8217brow30_col1 {
#             background-color:  lightgreen;
#             background-color:  lightgreen;
# ...

# %%
best_model = compare_models(n_select=5)
# Out:
# <style  type="text/css" >
#     #T_d9482408_2701_11eb_ae4e_98fa9bd8217b th {
#           text-align: left;
#     }    #T_d9482408_2701_11eb_ae4e_98fa9bd8217brow0_col0 {
#             text-align:  left;
#         }    #T_d9482408_2701_11eb_ae4e_98fa9bd8217brow0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_d9482408_2701_11eb_ae4e_98fa9bd8217brow0_col2 {
#             : ;
#             text-align:  left;
#         }    #T_d9482408_2701_11eb_ae4e_98fa9bd8217brow0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_d9482408_2701_11eb_ae4e_98fa9bd8217brow0_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_d9482408_2701_11eb_ae4e_98fa9bd8217brow0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_d9482408_2701_11eb_ae4e_98fa9bd8217brow0_col6 {
#             : ;
#             text-align:  left;
# ...
